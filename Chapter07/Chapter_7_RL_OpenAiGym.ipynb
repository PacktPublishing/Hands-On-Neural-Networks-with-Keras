# %%
import numpy as np
import gym
from gym import envs

# %%
#  This will print allavailable environemnts

#print(envs.registry.all())

# %%
#environment is loaded via the gym.make() command

env = gym.make('Taxi-v2')#MountainCar-v0

# %%
# running env.reset() returns the initial state of the environment

print('Initial state of environment:' , env.reset())
env.render()
# Out:
# Initial state of environment: 204
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+

# %%
env.observation_space.n
# Out:
# 500

# %% [markdown]
# #### Visualizing current state
#
# Next, We visualize the current state, using render()
#
# In the environment we are about to see:
#
# 1. The yellow square represents the taxi
# 2. The (“|”) represents a wall, the blue letter represents the pick-up location,
# 3. letters denoting passangers to pick up and drop off.
#
# The taxi will turn green when it has a passenger aboard.

# %%
#Visualize current state
env.render()
# Out:
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+

# %% [markdown]
# #### Understanding action space
# Exploring the actions available to the agent
#
# There are a total of six actions available.
# Gym may not always tell you what these actions mean,
# In this environment, the six possible actions are:
# 1. down (0),
# 2. up (1),
# 3. right (2),
# 4. left (3),
# 5. pick-up (4),
# 6. and drop-off (5)

# %%
env.action_space.n
#env.env.get_action_meanings()
# Out:
# 6

# %%
#render current position
env.render()

#move down
env.step(0)

#render new position
env.render()
# Out:
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)

# %%
# env.step(i) will return four variables
# They are defiend as (in order) the state, reward, done, info

env.step(1)
# Out:
# (204, -1, False, {'prob': 1.0})

# %%
# Overriding current state
env.env.s = 114
env.render()
# Out:
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)

# %%
#Move down

env.step(0)
# Out:
# (214, -1, False, {'prob': 1.0})

# %%
env.render()
# Out:
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)

# %%
#Change lanes

env.step(2)
# Out:
# (234, -1, False, {'prob': 1.0})

# %%
env.render()
# Out:
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)

# %%
#Change in reward if attempt to pickup at wrong location, penalizing agent

env.step(4)
# Out:
# (234, -10, False, {'prob': 1.0})

# %% [markdown]
# ### Stochastic Solution
#
# The environment is considered solved when you successfully pick up a passenger and drop them off at their desired location.
# Upon doing this, you will receive a reward of 20 and done will equal True. Lets see how many random tries it takes our agent to solve this rather simple environment

# %%
env.action_space.sample()
# Out:
# 4

# %%
# Overriding current state, used for reproducibility
state = env.env.s = 114

# counter tracks number of moves made
counter = 0

#No reward to begin with
reward = None

dropoffs = 0

#loop through random actions until successful dropoff (20 points)

while reward != 20:
    state, reward, done, info = env.step(env.action_space.sample())
    counter += 1
    print(counter)
    env.render()

print(counter, dropoffs)
# Out:
# 1
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
# 2
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
# 3
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# 4
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# 5
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# 6
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# 7
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# 8
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# 9
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# ...

# %% [markdown]
# ### Basic Q learning algorithm.

# %%
#Q-table, functions as agent's memory of state action pairs
Q = np.zeros([env.observation_space.n, env.action_space.n])

#track reward
R = 0

#discount factor
gamma = 0.85

# Track successful dropoffs
dropoffs_done = 0

#Run for 1000 episodes
for episode in range(1,1001):
    done = False
    
    #Initialize reward
    R, reward = 0,0
    
    #Initialize state
    state = env.reset()
    
    counter=0
    
    while done != True:
        
            counter+=1
        
            #Pick action with highest Q value
            action = np.argmax(Q[state]) 
            
            #Stores future state for compairason
            new_state, reward, done, info = env.step(action)
            
            #Update state action pair using reward and max Q-value for the new state
            Q[state,action] += gamma * (reward + np.max(Q[new_state]) - Q[state,action]) 
            
            #Update reward
            R += reward  
            
            #Update state
            state = new_state
            
            #Check how many times agent completes task
            if reward == 20:
                dropoffs_done +=1
                
    #Print reward every 50 episodes        
    if episode % 50 == 0:
        print('Episode {}   Total Reward: {}   Dropoffs done: {}  Time-Steps taken {}'
              .format(episode,R, dropoffs_done, counter))
# Out:
# Episode 50   Total Reward: -30   Dropoffs done: 19  Time-Steps taken 51
# Episode 100   Total Reward: 14   Dropoffs done: 66  Time-Steps taken 7
# Episode 150   Total Reward: -5   Dropoffs done: 116  Time-Steps taken 26
# Episode 200   Total Reward: 14   Dropoffs done: 166  Time-Steps taken 7
# Episode 250   Total Reward: 12   Dropoffs done: 216  Time-Steps taken 9
# Episode 300   Total Reward: 5   Dropoffs done: 266  Time-Steps taken 16
# Episode 350   Total Reward: 11   Dropoffs done: 316  Time-Steps taken 10
# Episode 400   Total Reward: 11   Dropoffs done: 366  Time-Steps taken 10
# Episode 450   Total Reward: 7   Dropoffs done: 416  Time-Steps taken 14
# Episode 500   Total Reward: 9   Dropoffs done: 466  Time-Steps taken 12
# Episode 550   Total Reward: 7   Dropoffs done: 516  Time-Steps taken 14
# Episode 600   Total Reward: 7   Dropoffs done: 566  Time-Steps taken 14
# Episode 650   Total Reward: 11   Dropoffs done: 616  Time-Steps taken 10
# ...

# %% [markdown]
# After so many episodes, the algorithm will converge and determine the optimal action for every state using the Q table, ensuring the highest possible reward. We now consider the environment problem solved.
#
# ### MsPacman
#
# Now that we solved a very simple environment, you can try experiment with a more complicated Atari environment—Ms. Pacman.

# %%
env = gym.make("MsPacman-v0")
state = env.reset()

# %%
#our current state is represented by a 210x160x3 Tensor.
#This represents the height, length, and the three RGB color channels of the Atari game
#or, simply put, the pixels

state.shape
# Out:
# (210, 160, 3)

# %%
env.render()
# Out:
# True

# %%
env.action_space.n
# Out:
# 9

# %%
env.env.get_action_meanings()
# Out:
# ['NOOP',
#  'UP',
#  'RIGHT',
#  'LEFT',
#  'DOWN',
#  'UPRIGHT',
#  'UPLEFT',
#  'DOWNRIGHT',
#  'DOWNLEFT']

# %%
import time


#Solve 5 times
for i in range(5):
    counter=0
    state = env.reset()
    reward, info, done = None, None, None
    while done != True:
        counter+=1
        state, reward, done, info = env.step(env.action_space.sample())
        env.render()

    #Pause after each solve
    time.sleep(1.5)
    print('Time steps per episodes:', counter)
# Out:
# Time steps per episodes: 716
# Time steps per episodes: 607
# Time steps per episodes: 568
# Time steps per episodes: 687
# Time steps per episodes: 590

# %%
# Dependencies #

# ! pip install keras-rl
# ! pip install gym
# ! pip install --no-index -f https://github.com/Kojoley/atari-py/releases atari_py
